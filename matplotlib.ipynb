# %% [markdown]
# ## What is Matplotlib?
# * Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# - pip install matplotlib

# %%
import matplotlib

# Checking Matplotlib Version
print(matplotlib.__version__)
# Out:
# 3.3.4

# %% [markdown]
# ## Pyplot
# * Most of the Matplotlib utilies lies under the __pyplot__ submodule, and are usually imported under the __plt__ alias:
# * The __plot()__ function is used to draw pionts (markers) in a diagram.
# * Parameter 1 is an array containing _x-axis_ and parameter 2 is an array containing the points _y-axis_

# %%
import matplotlib.pyplot as plt 
import numpy as np 

# Draw a line in a diagram from position (0,0) to position(6, 250)

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Plotting Without Line
# * To plot only the markers, you can use shortcut string notation parameters 'o', which means 'rings'.

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ## Mutliple Points
# * You can plot as many points as you like, just make usere you have the same number of points in both axis.

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Default X-Points
# * If we do nto specify the points in the x-axis, they will get the default values 0,1,2,3 (etc. depending on the length of the y-points).
# * So, if we take the same example as above, and leave out the x-points, the diagram will look like this
# * The x-points in the example above is [0,1,2,3,4,5]

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# ## Markers
# * You can use the keyword argumentss __marker__ to emphasize each point with a specified marker:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker='o')
plt.show()

# You can also mark each point with differet references eg
# plt.plot(ypoints, marker = '*')

# ************* MARKER REFERENCES ******************
# 'o' 	Circle
# '*' 	Star
# '.' 	Point
# ',' 	Pixel
# 'x' 	X
# 'X' 	X(filled)
# '+' 	Plus
# 'P' 	Plus(filled)
# 's' 	Square
# 'D' 	Diamond
# 'd' 	Diamond(thin)
# 'p' 	Pentagon
# 'H' 	Hexagon
# 'h' 	Hexagon
# 'v' 	Triangle Down
# '^' 	Triangle Up
# '<' 	Triangle Left
# '>' 	Triangle Right
# '1' 	Tri Down
# '2' 	Tri Up
# '3' 	Tri Left
# '4' 	Tri Right
# '|' 	Vline
# '_' 	Hline

# %% [markdown]
# #### Format Strings fmt
# * You can also use the shortcut string notation parameter to specify the marker
# * The parameter is also calle __fmt__, and is writtern with this syntax: __marker|line|color__

# %%
# Mark each point with a circle:

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# ### Line Reference
# * '-' 	Solid line
# * ':' 	Dotted line
# * '--' 	Dashed line
# * '-.' 	Dashed/dotted line
#
# ### Color References
# * 'r' 	Red
# * 'g' 	Green
# * 'b' 	Blue
# * 'c' 	Cyan
# * 'm' 	Magenta
# * 'y' 	Yellow
# * 'k' 	Black
# * 'w' 	White

# %% [markdown]
# ## Marker Size
# * You can use __markersize__ or the shorter version __ms__ to set the size of the markers:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker='o', ms=20)
plt.show()

# %% [markdown]
# ## Marker Color
# * You can use __markeredgecolor__ or the shorter mec to set the __color__ of the edge of the markers:

# %%
ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# * you can use the keyword argument __markerfacecolot__ or the shorter __mfc__ to set the color inside the edge of the markers:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker='o', ms=20, mfc='r')
plt.show()

# %% [markdown]
# * Use both the __mec__ and __mfc__ arguments to color of the entire marker:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker='o', ms=20, mec='r', mfc='r')
plt.show()

# %% [markdown]
# ##### You can also use Hexadecimal color values
# * plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
#
# ##### You can also any of the 140 supported color names
# * plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')

# %% [markdown]
# ## Matplotlib Line
# ### Linestyle
#
# * You can use the keyword argument __linestyle__ or shorter __ls__, to change the style of the plotted line:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle='dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle='dashed')

# %% [markdown]
# ## Shorter Syntax
# ### The line style can be written in shorter syntax:
#
# * __linestyle__ can be written as ls.
# * __dotted__ can be written as __:__.
# * __dashed__ can be written as __--__.
#
# #### Line Style

# %%
plt.plot(ypoints, ls=':')

# %% [markdown]
# ## Line Styles
#
# __You can choose any of these styles:__
#
# * 'solid' (default) 	'-'
# * 'dotted' 	':'
# * 'dashed' 	'--'
# * 'dashdot' 	'-.'
# * 'None' 	'' or ' '

# %% [markdown]
# ### Line Color
# * You can use the keyword arguments __color__ or the shorter __c__ to set the color of the line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color='r')
plt.show()

# %% [markdown]
# * plt.plot(ypoints, c = "#4CAF50")
# * plt.plot(ypoints, c = "hotpink")

# %% [markdown]
# ## Line Width
# * you can use the keyword argument __linewidth__ or the shorter __lw__ to change the width of the line.

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth='20.5')
plt.show()

# %% [markdown]
# ## Multiple Lines
#
# * You can plot as may lines as you like by  simpyly adding more plt.plot() functions:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# * You can also plot many lines by adding the points for the x- an y-axis for each line in the same plt.plot()
# * Draw two lines by specifying the x and y point values for both lines:\

# %% [markdown]
# * x1 = np.array([0, 1, 2, 3])
# * y1 = np.array([3, 8, 1, 10])
# * x2 = np.array([0, 1, 2, 3])
# * y2 = np.array([6, 2, 7, 11])
#
# * plt.plot(x1, y1, x2, y2)
# * plt.show()

# %% [markdown]
# ## Matplotlib Labels and Title
# ### Create Labels for a Plot
# * With Pyplot, you can use the __xlabel()__ and __ylable()__ functions to set a label for the x- and y-axis.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## Create a Title for a Plot
# ### With Pyplot, you can use the title() function to set a title for the plot.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## Set Font Properties for Title and Labels
# #### You can use the __fontdict()__ parameter in __xlabel()__, __ylabel()__, and __title()__ to set font properties for the title and labels.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family': 'serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'serif', 'color': 'darkred', 'size': 15}

plt.title("Sports Watch Data", fontdict=font1)
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage", fontdict=font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Position the Title
# * You can use the __loc()__ parameter in __title()__ to position the title.
# * Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Matplotlib Adding Grid Lines
# ### Add Grid Lines to a Plot
# * With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ### Specify Which Grid Lines to Display
# * You can use the __axis()__ parameter in the __grid()__ functions to specify which grid lines to display.
# * Legal values are: __'x', 'y'__, and __'both'__. Default values is __'both'__

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis='x')

plt.show()

# %% [markdown]
# ## Set Line Propeties for the Grid
# * You can also set the line properties of the grid, like this:
# > grid(color="color", linestyle='linestyle', linewidth='number')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color='green', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ## Matplotlib Subplots
# ### Disply Multiple Plots
#
# * With the __subplots()__ function you can draw multiple plots in one figure
#
# ### The subplots() Function
# * The subplots() funcitons takes three arguments that describes the layout of the figure
# * The layout is organized in rows and columns, which are represented by the __first__ and __second__ arguments.
# * The __third__ argument represents the index of the current plot.
# > plt.subplot(1, 2, 1)
# * _The figure has 1 row, 2 columns, and this plot is the first plot_
# > plt.subplot(1, 2, 2)
# * _The figure has 1 row, 2 columns, and this plo tis the second plot_

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x, y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x, y)

# %% [markdown]
# * You can draw as many plots you like on one figure, just descrive the number of rows, columns, and the index of the plot.

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ## Super Title
# * You can add a title to the entire figure with the __suptitle()__ function:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ## Matplotlib Scatter
# ### Creating Scatter Plot
# * With pyplot, you can use the scatter() function to draw a scatter plot.
# * The __scatter()__ function plots one dot for each observation.
# > It needs two arrays of the same length, one for the values of the x-axis, and one for the values on the y-axiz.

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Compare Plots

# %%
#day one, the age and speed of 13 cars:
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12])
y = np.array([100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ## Colors
# * You cna set your own color for each scatter plot with the __color__ of the __c__ argument:

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
plt.scatter(x, y, color='hotpink')

x = np.array([2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12])
y = np.array([100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85])
plt.scatter(x, y, color='#88c999')

plt.show()

# %% [markdown]
# ## Color Each Dot
# * You can even set a specific color for each dot by using an array of colors as value for the __c__ argument:
# > You cannot use the __color__ argument for this only the __c__ argument

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
colors = np.array(["red", "green", "blue", "yellow", "pink", "black",
                  "orange", "purple", "beige", "brown", "gray", "cyan", "magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## Color Map
# * The color map is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# ### How to use Colormaps
# * You can include the color map in the drawind by includding the __plt.colorbar()__ statement:

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# #### You can chooose any of the built in color maps:
# * Accent
#   	> Accent_r
# * Blues
#   	> Blues_r
# * BrBG
#   	> BrBG_r
# * BuGn
#   	> BuGn_r
# * BuPu
#   	> BuPu_r
# * CMRmap
#   	> CMRmap_r
# * Dark2
#   	> Dark2_r
# * GnBu
#   	> GnBu_r
# * Greens
#   	> Greens_r
# * Greys
#   	> terrain_r
# * twilight
#   	> twilight_r
# * twilight_shifted
#   	> twilight_shifted_r
# * viridis
#   	> viridis_r
# * winter
#   	> winter_r

# %% [markdown]
# ## Size
# * You can change the size of the dots with __s__ argument.

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ## Alpha
# * You can adjust the transparency of the dors with the __alpha__ argument.

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# ## Combinde Color Size and Alpha
# * You can combine a colormap with different sizes on the dots. Thi sis best visualized if the dots are transparent:

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Matplotlib Bars
# ## Creating Bars
# * With Pyplot, you can use __bar()__ function to draw bar graphs:
# * The bar() function takes arguments that describes the layout of the bars.
# * The categries and their values represented by the first and second argument as arrays.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %% [markdown]
# ## Horizontal Bars
# * If you want the bars to be displayed horizontally insted of vertically, use the _barh()__

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Bar Color
# * The __bar()__ and __barh()__ takes the keyword argument __color__ to set the color of the bars.
# * You can use any of the supported color names or you can use a hexadecimal value.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color="hotpink")
plt.show()

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color="#4CAF50")
plt.show()

# %% [markdown]
# ## Bar Width
# * The __bar()__ takes the keyword argument __width__ to set the width of the bars:
#
# ## Bar Height
# * The __barh()__ takes the keyword argument __height__ to set the height of the bars:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width=0.1)
plt.show()

# %% [markdown]
# # Histograms
# * Is a graph showing frequency distributions.
# * It is a graph showing the number of observations within each given interval.
# ## Create Histogram
# * In matplotlib we use __hist()__ to create histograms.
# * The __hist()__ function will use an array of number to create a histogram, the array is sent into the function as an argument.

# %%
# Generate and array with 250 values , where the values will concentrate around 170, and the standard deviation is 10
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # Pie Charts
# * With Pyplot, you can use the __pie()__ function to draw pie charts:
# > By default the plotting of the first wedge starts form the x-axis and move counterclockwise:

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# ### Labels
# * Add labels to the pie chart with the __label__ parameter

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels=mylabels)
plt.show()

# %% [markdown]
# ### Start Angle
# * As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
# * The startangle parameter is defined with an angle in degrees, default angle is 0

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels=mylabels, startangle=90)
plt.show()

# %% [markdown]
# ## Explode
# * The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# * Each value represents how far from the center each wedge is displayed:
#
# ## Shadow
# * Add a shadow to the pie chart by setting the shadows parameter to True:
#
# ## Colors
# * You can set the color of each wedge with the colors parameter.
#
# * The colors parameter, if specified, must be an array with one value for each wedge:
#
# ## Legend
# * To add a header to the legend, add the title parameter to the legend function.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels=mylabels, explode=myexplode)
plt.show()

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels=mylabels, explode=myexplode, shadow=True)
plt.show()

# You can use the hexadecimal values or any of the supported color names.
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels=mylabels, colors=mycolors)
plt.show()

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels=mylabels)
plt.legend(title="Four Fruits:")
plt.show()
